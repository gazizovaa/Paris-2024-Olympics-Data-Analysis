# %%
import pandas as pd
import os

# %%
pwd
# Out:
# 'C:\\Users\\User'

# %%
df = pd.read_csv('C:/Users/User/Music/paris_olympics_results.csv', encoding='ISO-8859-1')
df.head()
# Out:
#        NOC   Medal            Name       Sport                  Event  \
# 0  Albania  Bronze  Chermen Valiev   Wrestling  Men's freestyle 74 kg
# 1  Albania  Bronze    Islam Dudaev   Wrestling  Men's freestyle 65 kg
# 2  Algeria    Gold   Kaylia Nemour  Gymnastics    Women's uneven bars
# 3  Algeria    Gold    Imane Khelif      Boxing          Women's 66 kg
# 4  Algeria  Bronze  Djamel Sedjati   Athletics            Men's 800 m
#
#         Date
# 0  8/10/2024
# 1  8/11/2024
# 2   8/4/2024
# 3   8/9/2024
# 4  8/10/2024

# %%
df.tail()
# Out:
#              NOC   Medal               Name      Sport                  Event  \
# 1034  Uzbekistan    Gold  Razambek Zhamalov  Wrestling  Men's freestyle 74 kg
# 1035  Uzbekistan  Silver   Svetlana Osipova  Taekwondo         Women's +67 kg
# 1036  Uzbekistan    Gold   Ulugbek Rashitov  Taekwondo            Men's 68 kg
# 1037      Zambia  Bronze   Muzala Samukonga  Athletics            Men's 400 m
# 1038      Zambia  Bronze   Muzala Samukonga  Athletics            Men's 400 m
#
#            Date
# 1034  8/10/2024
# 1035  8/10/2024
# 1036   8/8/2024
# 1037   8/7/2024
# 1038   8/7/2024

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1039 entries, 0 to 1038
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NOC     1039 non-null   object
#  1   Medal   1039 non-null   object
#  2   Name    1039 non-null   object
#  3   Sport   1039 non-null   object
#  4   Event   1039 non-null   object
#  5   Date    1039 non-null   object
# dtypes: object(6)
# memory usage: 48.8+ KB

# %%
df.shape
# Out:
# (1039, 6)

# %%
df.describe()
# Out:
#          NOC   Medal                                               Name  \
# count   1039    1039                                               1039
# unique    92       5                                                799
# top      USA  Bronze  Lennart van Lierop\nFinn Florijn\nTone Wieten\...
# freq     126     376                                                 81
#
#             Sport               Event       Date
# count        1039                1039       1039
# unique         38                 399         17
# top     Athletics  Women's tournament  8/10/2024
# freq          145                  22        110

# %%
df.values
# Out:
# array([['Albania', 'Bronze', 'Chermen Valiev', 'Wrestling',
#         "Men's freestyle 74 kg", '8/10/2024'],
#        ['Albania', 'Bronze', 'Islam Dudaev', 'Wrestling',
#         "Men's freestyle 65 kg", '8/11/2024'],
#        ['Algeria', 'Gold', 'Kaylia Nemour', 'Gymnastics',
#         "Women's uneven bars", '8/4/2024'],
#        ...,
#        ['Uzbekistan', 'Gold', 'Ulugbek Rashitov', 'Taekwondo',
#         "Men's 68 kg", '8/8/2024'],
#        ['Zambia', 'Bronze', 'Muzala Samukonga', 'Athletics',
#         "Men's 400 m", '8/7/2024'],
#        ['Zambia', 'Bronze', 'Muzala Samukonga', 'Athletics',
#         "Men's 400 m", '8/7/2024']], dtype=object)

# %%
df.columns
# Out:
# Index(['NOC', 'Medal', 'Name', 'Sport', 'Event', 'Date'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1039, step=1)

# %%
df.sort_values(["Name", "Event", "Date"], ascending = [True, False, True])
# Out:
#              NOC   Medal                                               Name  \
# 898          USA  Bronze                                       Aaron Brooks
# 678     Malaysia  Bronze                             Aaron ChiaSoh Wooi Yik
# 1024  Uzbekistan    Gold                                 Abdumalik Khalokov
# 131       Canada  Silver  Abigail DentCaileigh FilmerKasia Gruchalla-Wes...
# 651        Kenya  Bronze                                    Abraham Kibiwot
# ...          ...     ...                                                ...
# 837        Spain  Bronze                                      Álvaro Martín
# 828        Spain    Gold                         Álvaro Martín\nMaría Pérez
# 248     Columbia  Silver                                      Ángel Barajas
# 683       Mexico  Bronze     Ángela RuizAlejandra ValenciaAna Paula Vázquez
# 323       France  Silver                                     Élodie Clouvel
#
# ...

# %%
is_gymnastics = df["Sport"] == "Skateboarding"
is_gold = df["Medal"] == "Gold"

df[is_gymnastics & is_gold]
# Out:
#            NOC Medal            Name          Sport           Event       Date
# 15   Australia  Gold      Arisa Trew  Skateboarding    Women's park   8/6/2024
# 47   Australia  Gold   Keegan Palmer  Skateboarding      Men's park   8/7/2024
# 600      Japon  Gold  Coco Yoshizawa  Skateboarding  Women's street  7/28/2024
# 642      Japon  Gold   Yuto Horigome  Skateboarding    Men's street  7/29/2024

# %%
# Rename "Country" column to "NOC"
df.rename(columns = {"Country": "NOC"}, inplace = True)
print(df)
# Out:
#              NOC   Medal               Name       Sport  \
# 0        Albania  Bronze     Chermen Valiev   Wrestling
# 1        Albania  Bronze       Islam Dudaev   Wrestling
# 2        Algeria    Gold      Kaylia Nemour  Gymnastics
# 3        Algeria    Gold       Imane Khelif      Boxing
# 4        Algeria  Bronze     Djamel Sedjati   Athletics
# ...          ...     ...                ...         ...
# 1034  Uzbekistan    Gold  Razambek Zhamalov   Wrestling
# 1035  Uzbekistan  Silver   Svetlana Osipova   Taekwondo
# 1036  Uzbekistan    Gold   Ulugbek Rashitov   Taekwondo
# 1037      Zambia  Bronze   Muzala Samukonga   Athletics
# 1038      Zambia  Bronze   Muzala Samukonga   Athletics
#
#                       Event       Date
# 0     Men's freestyle 74 kg  8/10/2024
# 1     Men's freestyle 65 kg  8/11/2024
# 2       Women's uneven bars   8/4/2024
# 3             Women's 66 kg   8/9/2024
# 4               Men's 800 m  8/10/2024
# ...                     ...        ...
# ...

# %%
japan_medal_mapping = {
    'Akari Fujinami': 'Gold',
    'Ami Yuasa': 'Gold',
    'Coco Yoshizawa': 'Gold',
    'Daichi Takatani': 'Silver',
    'Haruka Funakubo': 'Bronze',
    'Haruka Kitaguchi': 'Gold',
    'Hideki Matsuyama': 'Bronze',
    'Hifumi Abe': 'Gold',
    'Hina Hayata': 'Bronze',
    'Kenichiro Fumita': 'Gold',
    'Koki Kano': 'Gold',
    'Kokona Hiraki': 'Silver',
    'Kotaro Kiyooka': 'Gold',
    'Liz Akama': 'Silver',
    'Nao Kusaka': 'Gold',
    'Natsumi Tsunoda': 'Gold',
    'Nonoka Ozaki': 'Bronze',
    'Rei Higuchi': 'Gold',
    'Rikuto Tamai': 'Silver',
    'Ryuju Nagayama': 'Bronze',
    'Sakura Motoki': 'Gold',
    'Sanshiro Murao': 'Silver',
    'Shinnosuke Oka': 'Gold',
    'Shinnosuke Oka': 'Gold',
    'Shinnosuke Oka': 'Bronze',
    'Soichi Hashimoto': 'Bronze',
    'Sorato Anraku': 'Silver',
    'Taishu Sato': 'Silver',
    'Takaaki Sugino\nShinnosuke Oka\nDaiki Hashimoto\nKazuma Kaya\nWataru Tanigawa': 'Gold',
    'Kazuki limura\nKyosuke Matsuyama\nTakahiro Shikine\nYudai Nagano': 'Gold',
    'Akira Komata\nKoki Kano\nMasaru Yamada\nKazuyasu Minobe': 'Silver',
    'Uta Abe\nSoichi Hashimoto\nMiku Tashiro\nSanshiro Murao\nRika Takayama\nTatsuru Saito\nTakanori Nagase\nAaron Wold\nHaruka Funakubo\nAkira Sone\nRyuju Nagayama\nNatsumi Tsunoda\nHifumi Abe': 'Gold',
    'Keiju Okada\nMiho Yoshioka': 'Silver',
    'Hina Hayata\nMiwa Harimoto\nMiu Hirano': 'Silver',
    'Yoshiaki Oiwa\nKazuma Tomoto\nToshiyuki Tanaka\nRyuzo Kitajima': 'Bronze',
    'Sera Azuma\nYuka Ueno\nKarin Miyawaki\nKomaki Kikuchi': 'Bronze',
    'Yuta Watanabe\nArisa Higashino': 'Bronze',
    'Nami Matsuyama\nChiharu Shida': 'Bronze',
    'Risa Takashima\nSeri Ozaki\nMisaki Emura\nShihomi Fukushima': 'Bronze',
    'Takanori Nagase': 'Gold',
    'Tomoyuki Matsushita': 'Silver',
    'Tsugumi Sakurai': 'Gold',
    'Yui Susaki': 'Bronze',
    'Yuka Kagami': 'Gold',
    'Yuto Horigome': 'Gold'
}

# %%
df["Medal"] = df["Medal"].fillna(df["Name"].map(japan_medal_mapping))

# %%
china_medal_mapping = { 
    'Cao Liguo': 'Silver',
    'Cao Yuan': 'Gold',
    'Chang Yani': 'Bronze',
    'Chang Yuan': 'Gold',
    'Chen Meng': 'Gold',
    'Chen Yiwen': 'Gold',
    'Chen Yuxi': 'Silver',
    'Deng Lijuan': 'Silver',  
    'Deng Yawen': 'Gold',
    'Fan Zhendong': 'Gold',
    'Feng Bin': 'Silver',
    'Feng Ziqi': 'Bronze',
    'Guo Qing': 'Silver',
    'He Bingjiao': 'Silver',
    'Hong Kexin': 'Bronze',
    'Hou Zhihui': 'Gold',
    'Huang Yuting': 'Silver',
    'Huang Yuting\nSheng Lihao': 'Gold',
    'Chang Yani\nChen Yiwen': 'Gold',
    'Lian Junjie\nYang Hao': 'Gold',
    'Wang Chuqin\nSun Yingsha': 'Gold',
    'Chen Yuxi\nQuan Hongchan': 'Gold',
    'Long Daoyi\nWang Zongyuan': 'Gold',
    'Zhng Siwei\nHuang Yaqiong': 'Gold',
    'Chen Qingchen\nJia Yifan': 'Gold',
    'Xu Jiayu\nQin Haiyang\nSun Jiajun\nPan Zhanle\nWang Changhao': 'Gold',
    'Chang Hao\nFeng Yu\nWang Ciyue\nWang Liuyi\nWang Qianyi\nXiang Binxuan\nXiao Yanning\nZhang Yayi': 'Gold',
    'Xu Shixiao\nSun Mengya': 'Gold',
    'Fan Zhendong\nMa Long\nWang Chuqin': 'Gold',
    'Ding Xinyi\nGuo Qiqi\nHao Ting\nHuang Zhangjiayang\nPu Yanzhu\nWang Lanjing': 'Gold',
    'Chen Meng\nSun Yingsha\nWang Manyu': 'Gold',
    'Wang Liuyi\nWang Qianyi': 'Gold',
    'An Qixuan\nLi Jiaman\nYang Xiaolei': 'Silver',
    'Liu Yang\nSu Weide\nXiao Ruoteng\nZhang Boheng\nZou Jingyuan': 'Silver',
    'Wang Xinyu\nZhang Zhizhen': 'Silver',
    'Liu Shengshu\nTan Ning': 'Silver',
    'Qin Haiyang\nYang Junxuan\nXu Jiayu\nPan Zhanle\nTang Qianting\nZhang Yufei': 'Silver',
    'Liang Weikeng\nWang Chang': 'Silver',
    'China womens national field hockey team\nYe Jiao\nGu Bingfeng\nYang Liu\nZhang Ying\nChen Yi\nMa Ning\nLi Hong\nOu Zixia\nDan Wen\nZou Meirong\nHe Jiangxin\nFan Yunxia\nChen Yang\nXu Wenyu\nZhong Jiaqi\nTan Jinzhuang\nYu Anhui': 'Silver',
    'Cheng Yuije\nWu Qingfeng\nYang Junxuan\nYu Yiting\nZhang Yufei': 'Bronze',
    'Ge Chutong\nKong Yaqi\nLi Bingjie\nLiu Yaxin\nTang Muhan\nYang Junxuan': 'Bronze',
    'Wan Letian\nTang Qianting\nZhang Yufei\nYang Junxuan\nWang Xue`er\nYu Yiting\nWu Qingfeng': 'Bronze',
    'Jiang Yiting\nLyu Jianlin': 'Bronze',
    'Li Fabin': 'Gold',
    'Li Qian': 'Gold',
    'Li Wenwen': 'Gold',
    'Li Yuehong': 'Gold',
    'Liang Yushuai': 'Bronze',
    'Lin Xiyu': 'Bronze',
    'Liu HaoJi Bowen': 'Gold',
    'Liu Huanhua': 'Gold',
    'Liu Qingyi': 'Bronze',
    'Liu Yang': 'Gold',
    'Liu Yukun': 'Gold',
    'Luo Shifang': 'Gold',  
    'Ma Zhenzhao': 'Bronze',
    'Meng Lingzhe': 'Bronze',
    'Pan Zhanle': 'Gold',
    'Pang Qianyu': 'Bronze',
    'Qi Ying': 'Silver',
    'Qiu Qiyuan': 'Silver',
    'Quan Hongchan': 'Gold',
    'Sheng Lihao': 'Gold',
    'Song Jiayuan': 'Bronze',
    'Sun Yingsha': 'Silver',
    'Tang Qianting': 'Silver',
    'Wang Shun': 'Bronze',
    'Wang Xinjie': 'Bronze',
    'Wang Zisai': 'Silver',
    'Wang Zongyuan': 'Silver',
    'Wu Peng': 'Silver',
    'Wu Yu': 'Gold',
    'Xiao Ruoteng': 'Bronze',
    'Xie Siyi': 'Gold',
    'Xie Yu': 'Gold',
    'Xu Jiayu': 'Silver',
    'Yan Langyu': 'Bronze',
    'Yang Jiayu': 'Gold',
    'Yang Liu': 'Silver',  
    'Yang Wenlu': 'Silver',
    'Zhang Boheng': 'Silver',
    'Zhang Boheng': 'Bronze',
    'Zhang Qiongyue': 'Bronze',
    'Zhang Yufei': 'Bronze',
    'Zhang Yufei': 'Bronze',
    'Zhang Yufei': 'Bronze',
    'Zhao Jie': 'Bronze',
    'Zheng Qinwen': 'Gold',
    'Zhou Yaqin': 'Silver',
    'Zou Jingyuan': 'Gold',
    'Zou Jingyuan': 'Silver'
}

# %%
df["Medal"] = df["Medal"].fillna(df["Name"].map(china_medal_mapping))

# %%
df
# Out:
#              NOC   Medal               Name       Sport  \
# 0        Albania  Bronze     Chermen Valiev   Wrestling
# 1        Albania  Bronze       Islam Dudaev   Wrestling
# 2        Algeria    Gold      Kaylia Nemour  Gymnastics
# 3        Algeria    Gold       Imane Khelif      Boxing
# 4        Algeria  Bronze     Djamel Sedjati   Athletics
# ...          ...     ...                ...         ...
# 1034  Uzbekistan    Gold  Razambek Zhamalov   Wrestling
# 1035  Uzbekistan  Silver   Svetlana Osipova   Taekwondo
# 1036  Uzbekistan    Gold   Ulugbek Rashitov   Taekwondo
# 1037      Zambia  Bronze   Muzala Samukonga   Athletics
# 1038      Zambia  Bronze   Muzala Samukonga   Athletics
#
#                       Event       Date
# 0     Men's freestyle 74 kg  8/10/2024
# 1     Men's freestyle 65 kg  8/11/2024
# 2       Women's uneven bars   8/4/2024
# 3             Women's 66 kg   8/9/2024
# 4               Men's 800 m  8/10/2024
# ...                     ...        ...
# ...

# %%
df.to_csv('C:/Users/User/Music/paris_olympics_results.csv', index=False, encoding='ISO-8859-1')

# %%
df.isna().any()
# Out:
# NOC      False
# Medal    False
# Name     False
# Sport    False
# Event    False
# Date     False
# dtype: bool

# %%
df.isna().sum()
# Out:
# NOC      0
# Medal    0
# Name     0
# Sport    0
# Event    0
# Date     0
# dtype: int64

# %%
fill_sport_missing_values = {
    'Manu BhakerSarabjot Singh': 'Shooting',
    'Swapnil Kusale': 'Shooting'
}

# %%
df["Sport"] = df["Sport"].fillna(df["Name"].map(fill_sport_missing_values))

# %%
df.to_csv('C:/Users/User/Music/paris_olympics_results.csv', index=False, encoding='ISO-8859-1')

# %%
df.isna().sum()
# Out:
# NOC      0
# Medal    0
# Name     0
# Sport    0
# Event    0
# Date     0
# dtype: int64

# %%
df["NOC"] = df["NOC"].replace(to_replace="USA", value="United States")

# %%
df.loc[df["NOC"] == "Dominica"]
# Out:
#           NOC Medal         Name      Sport                Event      Date
# 289  Dominica  Gold  Thea LaFond  Athletics  Women's triple jump  8/3/2024
# 290  Dominica  Gold  Thea LaFond  Athletics  Women's triple jump  8/3/2024

# %%
# df = df.drop(290)
# df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[175], line 1
# ----> 1 df = df.drop(290)
#       2 df
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# ...

# %%
df.loc[df["NOC"] == "Dominica"]
# Out:
#           NOC Medal         Name      Sport                Event      Date
# 289  Dominica  Gold  Thea LaFond  Athletics  Women's triple jump  8/3/2024

# %%
df.loc[df["NOC"] == "Lithuania"]
# Out:
#            NOC   Medal                                               Name  \
# 670  Lithuania  Silver                                     Mykolas Alekna
# 671  Lithuania  Silver                                   Dominika Banevi?
# 672  Lithuania  Bronze                                  Viktorija Senkut?
# 673  Lithuania  Bronze  Evaldas DiaugysGintautas MatulisAurelijus Puk...
# 674  Lithuania  Silver                                     Mykolas Alekna
# 675  Lithuania  Silver                                   Dominika Banevi?
# 676  Lithuania  Bronze                                  Viktorija Senkut?
# 677  Lithuania  Bronze  Evaldas DiaugysGintautas MatulisAurelijus Puk...
#
#           Sport                  Event      Date
# 670   Athletics     Men's discus throw  8/7/2024
# 671    Breaking                B-Girls  8/9/2024
# 672      Rowing  Women's single sculls  8/3/2024
# 673  Basketball              Men's 3x3  8/5/2024
# 674   Athletics     Men's discus throw  8/7/2024
# ...

# %%
# df = df.drop(674)
# df
# Out:
#              NOC   Medal               Name       Sport  \
# 0        Albania  Bronze     Chermen Valiev   Wrestling
# 1        Albania  Bronze       Islam Dudaev   Wrestling
# 2        Algeria    Gold      Kaylia Nemour  Gymnastics
# 3        Algeria    Gold       Imane Khelif      Boxing
# 4        Algeria  Bronze     Djamel Sedjati   Athletics
# ...          ...     ...                ...         ...
# 1034  Uzbekistan    Gold  Razambek Zhamalov   Wrestling
# 1035  Uzbekistan  Silver   Svetlana Osipova   Taekwondo
# 1036  Uzbekistan    Gold   Ulugbek Rashitov   Taekwondo
# 1037      Zambia  Bronze   Muzala Samukonga   Athletics
# 1038      Zambia  Bronze   Muzala Samukonga   Athletics
#
#                       Event       Date
# 0     Men's freestyle 74 kg  8/10/2024
# 1     Men's freestyle 65 kg  8/11/2024
# 2       Women's uneven bars   8/4/2024
# 3             Women's 66 kg   8/9/2024
# 4               Men's 800 m  8/10/2024
# ...                     ...        ...
# ...

# %%
# df = df.drop(675)
# df
# Out:
#              NOC   Medal               Name       Sport  \
# 0        Albania  Bronze     Chermen Valiev   Wrestling
# 1        Albania  Bronze       Islam Dudaev   Wrestling
# 2        Algeria    Gold      Kaylia Nemour  Gymnastics
# 3        Algeria    Gold       Imane Khelif      Boxing
# 4        Algeria  Bronze     Djamel Sedjati   Athletics
# ...          ...     ...                ...         ...
# 1034  Uzbekistan    Gold  Razambek Zhamalov   Wrestling
# 1035  Uzbekistan  Silver   Svetlana Osipova   Taekwondo
# 1036  Uzbekistan    Gold   Ulugbek Rashitov   Taekwondo
# 1037      Zambia  Bronze   Muzala Samukonga   Athletics
# 1038      Zambia  Bronze   Muzala Samukonga   Athletics
#
#                       Event       Date
# 0     Men's freestyle 74 kg  8/10/2024
# 1     Men's freestyle 65 kg  8/11/2024
# 2       Women's uneven bars   8/4/2024
# 3             Women's 66 kg   8/9/2024
# 4               Men's 800 m  8/10/2024
# ...                     ...        ...
# ...

# %%
# df = df.drop(676)
# df
# Out:
#              NOC   Medal               Name       Sport  \
# 0        Albania  Bronze     Chermen Valiev   Wrestling
# 1        Albania  Bronze       Islam Dudaev   Wrestling
# 2        Algeria    Gold      Kaylia Nemour  Gymnastics
# 3        Algeria    Gold       Imane Khelif      Boxing
# 4        Algeria  Bronze     Djamel Sedjati   Athletics
# ...          ...     ...                ...         ...
# 1034  Uzbekistan    Gold  Razambek Zhamalov   Wrestling
# 1035  Uzbekistan  Silver   Svetlana Osipova   Taekwondo
# 1036  Uzbekistan    Gold   Ulugbek Rashitov   Taekwondo
# 1037      Zambia  Bronze   Muzala Samukonga   Athletics
# 1038      Zambia  Bronze   Muzala Samukonga   Athletics
#
#                       Event       Date
# 0     Men's freestyle 74 kg  8/10/2024
# 1     Men's freestyle 65 kg  8/11/2024
# 2       Women's uneven bars   8/4/2024
# 3             Women's 66 kg   8/9/2024
# 4               Men's 800 m  8/10/2024
# ...                     ...        ...
# ...

# %%
# df = df.drop(677)
# df
# Out:
#              NOC   Medal               Name       Sport  \
# 0        Albania  Bronze     Chermen Valiev   Wrestling
# 1        Albania  Bronze       Islam Dudaev   Wrestling
# 2        Algeria    Gold      Kaylia Nemour  Gymnastics
# 3        Algeria    Gold       Imane Khelif      Boxing
# 4        Algeria  Bronze     Djamel Sedjati   Athletics
# ...          ...     ...                ...         ...
# 1034  Uzbekistan    Gold  Razambek Zhamalov   Wrestling
# 1035  Uzbekistan  Silver   Svetlana Osipova   Taekwondo
# 1036  Uzbekistan    Gold   Ulugbek Rashitov   Taekwondo
# 1037      Zambia  Bronze   Muzala Samukonga   Athletics
# 1038      Zambia  Bronze   Muzala Samukonga   Athletics
#
#                       Event       Date
# 0     Men's freestyle 74 kg  8/10/2024
# 1     Men's freestyle 65 kg  8/11/2024
# 2       Women's uneven bars   8/4/2024
# 3             Women's 66 kg   8/9/2024
# 4               Men's 800 m  8/10/2024
# ...                     ...        ...
# ...

# %%
df.loc[df["NOC"] == "Lithuania"]
# Out:
#            NOC   Medal                                               Name  \
# 670  Lithuania  Silver                                     Mykolas Alekna
# 671  Lithuania  Silver                                   Dominika Banevi?
# 672  Lithuania  Bronze                                  Viktorija Senkut?
# 673  Lithuania  Bronze  Evaldas DiaugysGintautas MatulisAurelijus Puk...
#
#           Sport                  Event      Date
# 670   Athletics     Men's discus throw  8/7/2024
# 671    Breaking                B-Girls  8/9/2024
# 672      Rowing  Women's single sculls  8/3/2024
# 673  Basketball              Men's 3x3  8/5/2024

# %%
df.loc[df["NOC"] == "Zambia"]
# Out:
#          NOC   Medal              Name      Sport        Event      Date
# 1037  Zambia  Bronze  Muzala Samukonga  Athletics  Men's 400 m  8/7/2024
# 1038  Zambia  Bronze  Muzala Samukonga  Athletics  Men's 400 m  8/7/2024

# %%
# df = df.drop(1038)
# df
# Out:
#              NOC   Medal                   Name       Sport  \
# 0        Albania  Bronze         Chermen Valiev   Wrestling
# 1        Albania  Bronze           Islam Dudaev   Wrestling
# 2        Algeria    Gold          Kaylia Nemour  Gymnastics
# 3        Algeria    Gold           Imane Khelif      Boxing
# 4        Algeria  Bronze         Djamel Sedjati   Athletics
# ...          ...     ...                    ...         ...
# 1033  Uzbekistan  Bronze  Muzaffarbek Turoboyev        Judo
# 1034  Uzbekistan    Gold      Razambek Zhamalov   Wrestling
# 1035  Uzbekistan  Silver       Svetlana Osipova   Taekwondo
# 1036  Uzbekistan    Gold       Ulugbek Rashitov   Taekwondo
# 1037      Zambia  Bronze       Muzala Samukonga   Athletics
#
#                       Event       Date
# 0     Men's freestyle 74 kg  8/10/2024
# 1     Men's freestyle 65 kg  8/11/2024
# 2       Women's uneven bars   8/4/2024
# 3             Women's 66 kg   8/9/2024
# 4               Men's 800 m  8/10/2024
# ...

# %%
df.loc[df["NOC"] == "Zambia"]
# Out:
#          NOC   Medal              Name      Sport        Event      Date
# 1037  Zambia  Bronze  Muzala Samukonga  Athletics  Men's 400 m  8/7/2024

# %%
df
# Out:
#              NOC   Medal                   Name       Sport  \
# 0        Albania  Bronze         Chermen Valiev   Wrestling
# 1        Albania  Bronze           Islam Dudaev   Wrestling
# 2        Algeria    Gold          Kaylia Nemour  Gymnastics
# 3        Algeria    Gold           Imane Khelif      Boxing
# 4        Algeria  Bronze         Djamel Sedjati   Athletics
# ...          ...     ...                    ...         ...
# 1033  Uzbekistan  Bronze  Muzaffarbek Turoboyev        Judo
# 1034  Uzbekistan    Gold      Razambek Zhamalov   Wrestling
# 1035  Uzbekistan  Silver       Svetlana Osipova   Taekwondo
# 1036  Uzbekistan    Gold       Ulugbek Rashitov   Taekwondo
# 1037      Zambia  Bronze       Muzala Samukonga   Athletics
#
#                       Event       Date
# 0     Men's freestyle 74 kg  8/10/2024
# 1     Men's freestyle 65 kg  8/11/2024
# 2       Women's uneven bars   8/4/2024
# 3             Women's 66 kg   8/9/2024
# 4               Men's 800 m  8/10/2024
# ...

# %%
df.to_csv('C:/Users/User/Music/paris_olympics_results.csv', index=False, encoding='ISO-8859-1')
